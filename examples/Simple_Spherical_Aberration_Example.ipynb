# %%
import numpy as np
import matplotlib.pyplot as plt

import tracepy as tp

# %%
lens = {
    'name': 'lens',
    'action': 'refraction',
    'P': 2.,
    'kappa': -.004,
    'c': -.5,
    'Diam': 2.2
}

back_lens = {
    'name': 'back_lens',
    'action': 'refraction',
    'P': 1.,
    'c':.5,
    'kappa': -.004,
    'N': 1.5,
    'Diam': 2.2
}

stop = {
    'name': 'stop',
    'action': 'stop',
    'P': 3.,
    'Diam': 2.2
}

geo_1 = [back_lens, lens, stop]
ray_group = tp.ray_plane(geo_1, [0., 0., 0.], 1.1, d=[0.,0.,1.], nrays=100)

# %%
tp.plotyz(geo_1, ray_group)

# %%
tp.spotdiagram(geo_1, ray_group)

# %%
ray_group_2 = tp.ray_plane(geo_1, [0., 0., 0.], 1.1, d=[0.,0.,1.], nrays=1000)
tp.rayaberration(geo_1, ray_group_2)

# %%
vlens = {
    'name': 'stop',
    'vary': ['P']
}

vlens2 = {
    'name': 'back_lens',
    'vary': ['c', 'kappa', 'N']
}

vlens3 = {
    'name': 'lens',
    'vary': ['c', 'kappa']
}

vary_list = [vlens, vlens2, vlens3]

# %%
geo_opt = tp.optimize(geo_1, vary_list, typeof='least_squares')
ray_group_opt = tp.ray_plane(geo_opt, [0., 0., 0.], 1.1, d=[0.,0.,1.], nrays=100)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-6376813f06d7> in <module>()
# ----> 1 geo_opt = tp.optimize(geo_1, vary_list, typeof='least_squares')
#       2 ray_group_opt = tp.ray_plane(geo_opt, [0., 0., 0.], 1.1, d=[0.,0.,1.], nrays=100)
#
# C:\Python37\lib\site-packages\tracepy\optimize.py in optimize(geoparams, vary_dicts, typeof, max_iter)
#     120     if typeof == 'least_squares':
#     121         res = least_squares(get_rms, initial_guess, args=(geoparams, vary_dicts), max_nfev=max_iter,\
# --> 122                             bounds = param_bounds)
#     123     new_params = update_geometry(np.around(res.x, 3), geoparams, vary_dicts)
#     124     return new_params
#
# C:\Python37\lib\site-packages\scipy\optimize\_lsq\least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     914         result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     915                      gtol, max_nfev, x_scale, loss_function, tr_solver,
# --> 916                      tr_options.copy(), verbose)
#     917
#     918     elif method == 'dogbox':
#
# C:\Python37\lib\site-packages\scipy\optimize\_lsq\trf.py in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     126         return trf_bounds(
#     127             fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale,
# --> 128             loss_function, tr_solver, tr_options, verbose)
#     129
#     130
#
# C:\Python37\lib\site-packages\scipy\optimize\_lsq\trf.py in trf_bounds(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     339
#     340             x_new = make_strictly_feasible(x + step, lb, ub, rstep=0)
# --> 341             f_new = fun(x_new)
#     342             nfev += 1
#     343
#
# C:\Python37\lib\site-packages\scipy\optimize\_lsq\least_squares.py in fun_wrapped(x)
#     800
#     801     def fun_wrapped(x):
# --> 802         return np.atleast_1d(fun(x, *args, **kwargs))
#     803
#     804     if method == 'trf':
#
# C:\Python37\lib\site-packages\tracepy\optimize.py in get_rms(inputs, geoparams, vary_dicts)
#      70     raygroup_iter = ray_plane(params_iter, [0., 0., 0.], 1.1, d=[0.,0.,1.], nrays=50)
#      71     try:
# ---> 72         rms = spotdiagram(params_iter, raygroup_iter, optimizer=True)
#      73     except TraceError:
#      74         rms = 999.
#
# C:\Python37\lib\site-packages\tracepy\optplot.py in spotdiagram(geo_params, rays, pltparams, optimizer)
#      69
#      70     stop = geometry(geo_params[-1])
# ---> 71     X, Y, points_obj = _gen_object_points(stop, -1, rays)
#      72     rms = np.std(points_obj[:,[0,1]] - points_obj[:,[0,1]].mean(axis=0))
#      73     if optimizer:
#
# C:\Python37\lib\site-packages\tracepy\optplot.py in _gen_object_points(surface, surface_idx, rays)
#      44     #Round arrays to upper bound on accuracy.
#      45     points_obj = np.around(points_obj, 14)
# ---> 46     X, Y = points_obj[:,0], points_obj[:,1]
#      47     return X, Y, points_obj
#      48
#
# IndexError: too many indices for array

# %%
tp.plotyz(geo_opt, ray_group_opt)

# %%
tp.spotdiagram(geo_opt, ray_group_opt)

# %%
ray_group_3 = tp.ray_plane(geo_opt, [0., 0., 0.], 1.1, d=[0.,0.,1.], nrays=1000)
tp.rayaberration(geo_1, ray_group_3)
